# %% [markdown]
# # Fundamental Analysis using Dow30 Stocks

# %%
import pandas as pd 
import numpy as np
import datetime
from datetime import date
import time
import pickle
import math
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, KFold, RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, mean_absolute_error, mean_absolute_percentage_error
from xgboost import XGBRegressor
import xgboost as xgb
import sklearn as skl
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Bidirectional
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.metrics import RootMeanSquaredError, MeanSquaredError
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import keras.backend as K
import os
import tensorflow as tf

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 250)

# %%
dow30 = pd.read_csv('All_Data.csv')
dow30.rename(columns = {'date':'Date'}, inplace = True)
dow30 = dow30.drop(columns=['index'])
dow30['Date'] = pd.to_datetime(dow30['Date'])
dow30 = dow30.drop(columns=['high', 'low', 'open'])
dow30 = dow30.sort_values(by=['Stock', 'Date'], ascending=True)
dow30 = dow30.reset_index().drop(columns=['index'])

dates = dow30['Date']
stocks = dow30['Stock']
indices_to_dates = dates.to_dict()
indices_to_stocks = stocks.to_dict()
act_returns_mapping15 = dow30['15d_Return'].to_dict()
act_returns_mapping30 = dow30['30d_Return'].to_dict()
act_returns_mapping60 = dow30['60d_Return'].to_dict()
price_mapping = dow30['close'].to_dict()

dow30

# %% [markdown]
# ## Feature Generation

# %% [markdown]
# ### Percentage from monthly high, RSI

# %%
def get_monthly_highs(df):
    df = df.sort_values(by=['Stock', 'Date'], ascending=True)
    row = 0
    curr_month = df['Date'].loc[0].month
    highs=[]
    while (row < len(df)):
        closes = []
        count=0
        while (row<len(df)) and (df['Date'].loc[row].month == curr_month):
            closes.append(df['close'].loc[row])
            row+=1
            count+=1
        for i in range(0,count):
            highs.append(max(closes))
        if (row < len(df)):
            curr_month = df['Date'].loc[row].month
    
    return highs

# %%
def get_rsi(prices):
    periods = 14
    ema = True
    close_delta = prices.diff()

    # Make two series: one for lower closes and one for higher closes
    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    
    if ema == True:
        # Use exponential moving average
        ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    else:
        # Use simple moving average
        ma_up = up.rolling(window = periods, adjust=False).mean()
        ma_down = down.rolling(window = periods, adjust=False).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))
    return rsi

# %%
highs = np.array(get_monthly_highs(dow30))
dow30['Percent_from_mth_high'] = (highs / dow30['close']) - 1

RSI = dow30.groupby('Stock').apply(lambda x: get_rsi(x['close']))
rsi = np.array(RSI)
dow30['RSI'] = rsi

dow30orig = dow30.copy()

dow30
# Out:
#             Date  10YBond  30dBondRet  VIX_high   spy_close  spy_5dret  \
# 0     2019-03-11    2.643   -0.039956     16.43  260.370637        NaN
# 1     2019-03-12    2.605   -0.050656     14.70  261.352498        NaN
# 2     2019-03-13    2.611   -0.037242     14.05  263.082442        NaN
# 3     2019-03-14    2.630   -0.024119     13.84  262.914123        NaN
# 4     2019-03-15    2.593   -0.015939     13.28  264.207467        NaN
# ...          ...      ...         ...       ...         ...        ...
# 30025 2023-02-22    3.923    0.115439     23.63  398.540000  -0.034170
# 30026 2023-02-23    3.879    0.071251     22.43  400.660000  -0.032175
# 30027 2023-02-24    3.949    0.111142       NaN  396.380000  -0.029147
# 30028 2023-02-27    3.922    0.137141     22.02  397.730000  -0.023400
# 30029 2023-02-28    3.916    0.115352     21.37  396.260000  -0.007091
#
#        spy_10dret  spy_15dret  surprise_%  expected_growth  previous_surprise  \
# 0             NaN         NaN      0.0096        -0.438095             0.0429
# 1             NaN         NaN      0.0096        -0.438095             0.0429
# 2             NaN         NaN      0.0096        -0.438095             0.0429
# 3             NaN         NaN      0.0096        -0.438095             0.0429
# 4             NaN         NaN      0.0096        -0.438095             0.0429
# ...           ...         ...         ...              ...                ...
# 30025   -0.040102   -0.019534      0.1364        -0.126667             0.1063
# 30026   -0.024327   -0.024684      0.1364        -0.126667             0.1063
# 30027   -0.026309   -0.048947      0.1364        -0.126667             0.1063
# 30028   -0.025267   -0.035455      0.1364        -0.126667             0.1063
# 30029   -0.040138   -0.033111      0.1364        -0.126667             0.1063
#
#        days_after_earn_report  dividends_change  prev_div_change  \
# 0                        41.0          0.158730         0.105263
# 1                        42.0          0.158730         0.105263
# 2                        43.0          0.158730         0.105263
# 3                        44.0          0.158730         0.105263
# 4                        45.0          0.158730         0.105263
# ...                       ...               ...              ...
# 30025                    99.0          0.018182         0.018519
# 30026                   100.0          0.018182         0.018519
# 30027                   101.0          0.018182         0.018519
# 30028                   104.0          0.018182         0.018519
# 30029                   105.0          0.018182         0.018519
#
#        days_after_divid_report       close       volume  divCash  \
# 0                        314.0   43.229318  128044136.0      0.0
# 1                        315.0   43.715014  129870336.0      0.0
# 2                        316.0   43.908325  124130096.0      0.0
# 3                        317.0   44.396437   94318032.0      0.0
# 4                        318.0   44.973956  156171648.0      0.0
# ...                        ...         ...          ...      ...
# 30025                    370.0  144.240000    9947985.0      0.0
# 30026                    371.0  142.090000    7340419.0      0.0
# 30027                    372.0  142.470000    6874531.0      0.0
# 30028                    375.0  141.440000    5549099.0      0.0
# 30029                    376.0  142.130000    6018036.0      0.0
#
#         debtCurrent  taxAssets  investmentsCurrent   totalAssets  \
# 0               NaN        NaN                 NaN           NaN
# 1               NaN        NaN                 NaN           NaN
# 2               NaN        NaN                 NaN           NaN
# 3               NaN        NaN                 NaN           NaN
# 4               NaN        NaN                 NaN           NaN
# ...             ...        ...                 ...           ...
# 30025  1.427500e+10        0.0                 0.0  2.476560e+11
# 30026  1.427500e+10        0.0                 0.0  2.476560e+11
# 30027  1.427500e+10        0.0                 0.0  2.476560e+11
# 30028  1.427500e+10        0.0                 0.0  2.476560e+11
# 30029           NaN        NaN                 NaN           NaN
#
#             acctPay        accoci     inventory  totalLiabilities  \
# 0               NaN           NaN           NaN               NaN
# 1               NaN           NaN           NaN               NaN
# 2               NaN           NaN           NaN               NaN
# 3               NaN           NaN           NaN               NaN
# 4               NaN           NaN           NaN               NaN
# ...             ...           ...           ...               ...
# 30025  5.726300e+10 -1.078000e+10  6.470600e+10      1.675330e+11
# 30026  5.726300e+10 -1.078000e+10  6.470600e+10      1.675330e+11
# 30027  5.726300e+10 -1.078000e+10  6.470600e+10      1.675330e+11
# 30028  5.726300e+10 -1.078000e+10  6.470600e+10      1.675330e+11
# 30029           NaN           NaN           NaN               NaN
#
#             acctRec   intangibles          ppeq  deferredRev     cashAndEq  \
# 0               NaN           NaN           NaN          NaN           NaN
# 1               NaN           NaN           NaN          NaN           NaN
# 2               NaN           NaN           NaN          NaN           NaN
# 3               NaN           NaN           NaN          NaN           NaN
# 4               NaN           NaN           NaN          NaN           NaN
# ...             ...           ...           ...          ...           ...
# 30025  8.218000e+09  2.813700e+10  1.155440e+11          0.0  1.158700e+10
# 30026  8.218000e+09  2.813700e+10  1.155440e+11          0.0  1.158700e+10
# 30027  8.218000e+09  2.813700e+10  1.155440e+11          0.0  1.158700e+10
# 30028  8.218000e+09  2.813700e+10  1.155440e+11          0.0  1.158700e+10
# 30029           NaN           NaN           NaN          NaN           NaN
#
#        assetsNonCurrent  taxLiabilities  investments        equity  \
# 0                   NaN             NaN          NaN           NaN
# 1                   NaN             NaN          NaN           NaN
# 2                   NaN             NaN          NaN           NaN
# 3                   NaN             NaN          NaN           NaN
# 4                   NaN             NaN          NaN           NaN
# ...                 ...             ...          ...           ...
# 30025      1.599760e+11    1.566000e+10          0.0  7.225300e+10
# 30026      1.599760e+11    1.566000e+10          0.0  7.225300e+10
# 30027      1.599760e+11    1.566000e+10          0.0  7.225300e+10
# 30028      1.599760e+11    1.566000e+10          0.0  7.225300e+10
# 30029               NaN             NaN          NaN           NaN
#
#        retainedEarnings  deposits  assetsCurrent  investmentsNonCurrent  \
# 0                   NaN       NaN            NaN                    NaN
# 1                   NaN       NaN            NaN                    NaN
# 2                   NaN       NaN            NaN                    NaN
# 3                   NaN       NaN            NaN                    NaN
# 4                   NaN       NaN            NaN                    NaN
# ...                 ...       ...            ...                    ...
# 30025      7.794600e+10       0.0   8.768000e+10                    0.0
# 30026      7.794600e+10       0.0   8.768000e+10                    0.0
# 30027      7.794600e+10       0.0   8.768000e+10                    0.0
# 30028      7.794600e+10       0.0   8.768000e+10                    0.0
# 30029               NaN       NaN            NaN                    NaN
#
#                debt  debtNonCurrent  liabilitiesNonCurrent  \
# 0               NaN             NaN                    NaN
# 1               NaN             NaN                    NaN
# 2               NaN             NaN                    NaN
# 3               NaN             NaN                    NaN
# 4               NaN             NaN                    NaN
# ...             ...             ...                    ...
# 30025  6.538000e+10    5.110500e+10           6.612500e+10
# 30026  6.538000e+10    5.110500e+10           6.612500e+10
# 30027  6.538000e+10    5.110500e+10           6.612500e+10
# 30028  6.538000e+10    5.110500e+10           6.612500e+10
# 30029           NaN             NaN                    NaN
#
#        liabilitiesCurrent   sharesBasic  longTermDebtEquity  shareFactor  \
# 0                     NaN           NaN                 NaN          NaN
# 1                     NaN           NaN                 NaN          NaN
# 2                     NaN           NaN                 NaN          NaN
# 3                     NaN           NaN                 NaN          NaN
# 4                     NaN           NaN                 NaN          NaN
# ...                   ...           ...                 ...          ...
# 30025        1.014080e+11  2.714238e+09            0.707306          1.0
# 30026        1.014080e+11  2.714238e+09            0.707306          1.0
# 30027        1.014080e+11  2.714238e+09            0.707306          1.0
# 30028        1.014080e+11  2.714238e+09            0.707306          1.0
# 30029                 NaN           NaN                 NaN          NaN
#
#             bookVal       roa  currentRatio       roe  grossMargin  \
# 0               NaN       NaN           NaN       NaN          NaN
# 1               NaN       NaN           NaN       NaN          NaN
# 2               NaN       NaN           NaN       NaN          NaN
# 3               NaN       NaN           NaN       NaN          NaN
# 4               NaN       NaN           NaN       NaN          NaN
# ...             ...       ...           ...       ...          ...
# 30025  8.012300e+10  0.036383      0.864626  0.115714     0.243435
# 30026  8.012300e+10  0.036383      0.864626  0.115714     0.243435
# 30027  8.012300e+10  0.036383      0.864626  0.115714     0.243435
# 30028  8.012300e+10  0.036383      0.864626  0.115714     0.243435
# 30029           NaN       NaN           NaN       NaN          NaN
#
#        piotroskiFScore    epsQoQ  revenueQoQ  profitMargin        rps  \
# 0                  NaN       NaN         NaN           NaN        NaN
# 1                  NaN       NaN         NaN           NaN        NaN
# 2                  NaN       NaN         NaN           NaN        NaN
# 3                  NaN       NaN         NaN           NaN        NaN
# 4                  NaN       NaN         NaN           NaN        NaN
# ...                ...       ...         ...           ...        ...
# 30025              6.0 -1.594595    0.087444      0.243435  56.300517
# 30026              6.0 -1.594595    0.087444      0.243435  56.300517
# 30027              6.0 -1.594595    0.087444      0.243435  56.300517
# 30028              6.0 -1.594595    0.087444      0.243435  56.300517
# 30029              NaN       NaN         NaN           NaN        NaN
#
#            bvps          ncfi         capex         ncfx          ncff  \
# 0           NaN           NaN           NaN          NaN           NaN
# 1           NaN           NaN           NaN          NaN           NaN
# 2           NaN           NaN           NaN          NaN           NaN
# 3           NaN           NaN           NaN          NaN           NaN
# 4           NaN           NaN           NaN          NaN           NaN
# ...         ...           ...           ...          ...           ...
# 30025  29.51952 -4.381000e+09 -4.515000e+09 -231000000.0 -4.181000e+09
# 30026  29.51952 -4.381000e+09 -4.515000e+09 -231000000.0 -4.181000e+09
# 30027  29.51952 -4.381000e+09 -4.515000e+09 -231000000.0 -4.181000e+09
# 30028  29.51952 -4.381000e+09 -4.515000e+09 -231000000.0 -4.181000e+09
# 30029       NaN           NaN           NaN          NaN           NaN
#
#        sbcomp           ncf        payDiv  businessAcqDisposals  issrepayDebt  \
# 0         NaN           NaN           NaN                   NaN           NaN
# 1         NaN           NaN           NaN                   NaN           NaN
# 2         NaN           NaN           NaN                   NaN           NaN
# 3         NaN           NaN           NaN                   NaN           NaN
# 4         NaN           NaN           NaN                   NaN           NaN
# ...       ...           ...           ...                   ...           ...
# 30025     0.0 -2.335000e+09 -1.519000e+09          -114000000.0  1.190000e+09
# 30026     0.0 -2.335000e+09 -1.519000e+09          -114000000.0  1.190000e+09
# 30027     0.0 -2.335000e+09 -1.519000e+09          -114000000.0  1.190000e+09
# 30028     0.0 -2.335000e+09 -1.519000e+09          -114000000.0  1.190000e+09
# 30029     NaN           NaN           NaN                   NaN           NaN
#
#        issrepayEquity  investmentsAcqDisposals  freeCashFlow          ncfo  \
# 0                 NaN                      NaN           NaN           NaN
# 1                 NaN                      NaN           NaN           NaN
# 2                 NaN                      NaN           NaN           NaN
# 3                 NaN                      NaN           NaN           NaN
# 4                 NaN                      NaN           NaN           NaN
# ...               ...                      ...           ...           ...
# 30025   -2.961000e+09                      0.0  1.943000e+09  6.458000e+09
# 30026   -2.961000e+09                      0.0  1.943000e+09  6.458000e+09
# 30027   -2.961000e+09                      0.0  1.943000e+09  6.458000e+09
# 30028   -2.961000e+09                      0.0  1.943000e+09  6.458000e+09
# 30029             NaN                      NaN           NaN           NaN
#
#             depamor        ebitda  netIncComStock  epsDil  consolidatedIncome  \
# 0               NaN           NaN             NaN     NaN                 NaN
# 1               NaN           NaN             NaN     NaN                 NaN
# 2               NaN           NaN             NaN     NaN                 NaN
# 3               NaN           NaN             NaN     NaN                 NaN
# 4               NaN           NaN             NaN     NaN                 NaN
# ...             ...           ...             ...     ...                 ...
# 30025  2.755000e+09  1.877000e+09   -1.798000e+09   -0.66       -1.767000e+09
# 30026  2.755000e+09  1.877000e+09   -1.798000e+09   -0.66       -1.767000e+09
# 30027  2.755000e+09  1.877000e+09   -1.798000e+09   -0.66       -1.767000e+09
# 30028  2.755000e+09  1.877000e+09   -1.798000e+09   -0.66       -1.767000e+09
# 30029           NaN           NaN             NaN     NaN                 NaN
#
#        nonControllingInterests   shareswaDil       intexp  rnd   eps  \
# 0                          NaN           NaN          NaN  NaN   NaN
# 1                          NaN           NaN          NaN  NaN   NaN
# 2                          NaN           NaN          NaN  NaN   NaN
# 3                          NaN           NaN          NaN  NaN   NaN
# 4                          NaN           NaN          NaN  NaN   NaN
# ...                        ...           ...          ...  ...   ...
# 30025               31000000.0  2.711000e+09  584000000.0  0.0 -0.66
# 30026               31000000.0  2.711000e+09  584000000.0  0.0 -0.66
# 30027               31000000.0  2.711000e+09  584000000.0  0.0 -0.66
# 30028               31000000.0  2.711000e+09  584000000.0  0.0 -0.66
# 30029                      NaN           NaN          NaN  NaN   NaN
#
#        netIncDiscOps   grossProfit      shareswa          opex           ebt  \
# 0                NaN           NaN           NaN           NaN           NaN
# 1                NaN           NaN           NaN           NaN           NaN
# 2                NaN           NaN           NaN           NaN           NaN
# 3                NaN           NaN           NaN           NaN           NaN
# 4                NaN           NaN           NaN           NaN           NaN
# ...              ...           ...           ...           ...           ...
# 30025            0.0  3.720000e+10  2.711000e+09  3.450500e+10 -1.462000e+09
# 30026            0.0  3.720000e+10  2.711000e+09  3.450500e+10 -1.462000e+09
# 30027            0.0  3.720000e+10  2.711000e+09  3.450500e+10 -1.462000e+09
# 30028            0.0  3.720000e+10  2.711000e+09  3.450500e+10 -1.462000e+09
# 30029            NaN           NaN           NaN           NaN           NaN
#
#              netinc       revenue         ebit       taxExp         opinc  \
# 0               NaN           NaN          NaN          NaN           NaN
# 1               NaN           NaN          NaN          NaN           NaN
# 2               NaN           NaN          NaN          NaN           NaN
# 3               NaN           NaN          NaN          NaN           NaN
# 4               NaN           NaN          NaN          NaN           NaN
# ...             ...           ...          ...          ...           ...
# 30025 -1.798000e+09  1.528130e+11 -878000000.0  336000000.0  2.695000e+09
# 30026 -1.798000e+09  1.528130e+11 -878000000.0  336000000.0  2.695000e+09
# 30027 -1.798000e+09  1.528130e+11 -878000000.0  336000000.0  2.695000e+09
# 30028 -1.798000e+09  1.528130e+11 -878000000.0  336000000.0  2.695000e+09
# 30029           NaN           NaN          NaN          NaN           NaN
#
#                 sga       costRev  prefDVDs  quarter    year     marketCap  \
# 0               NaN           NaN       NaN      NaN     NaN           NaN
# 1               NaN           NaN       NaN      NaN     NaN           NaN
# 2               NaN           NaN       NaN      NaN     NaN           NaN
# 3               NaN           NaN       NaN      NaN     NaN           NaN
# 4               NaN           NaN       NaN      NaN     NaN           NaN
# ...             ...           ...       ...      ...     ...           ...
# 30025  3.450500e+10  1.156130e+11       0.0      3.0  2023.0  3.889864e+11
# 30026  3.450500e+10  1.156130e+11       0.0      3.0  2023.0  3.831883e+11
# 30027  3.450500e+10  1.156130e+11       0.0      3.0  2023.0  3.842131e+11
# 30028  3.450500e+10  1.156130e+11       0.0      3.0  2023.0  3.814354e+11
# 30029           NaN           NaN       NaN      NaN     NaN  3.832962e+11
#
#        enterpriseVal    peRatio   pbRatio  trailingPEG1Y  \
# 0                NaN        NaN       NaN            NaN
# 1                NaN        NaN       NaN            NaN
# 2                NaN        NaN       NaN            NaN
# 3                NaN        NaN       NaN            NaN
# 4                NaN        NaN       NaN            NaN
# ...              ...        ...       ...            ...
# 30025   4.427794e+11  43.379775  5.383672      -0.272043
# 30026   4.369813e+11  42.733168  5.303424      -0.267988
# 30027   4.380061e+11  42.847452  5.317608      -0.268704
# 30028   4.352284e+11  42.537683  5.279163      -0.266762
# 30029   4.370892e+11  42.745198  5.304917      -0.268063
#
#        Debt-to-Equity_Ratio  DividendsYield  PayoutRatio  Acc_Rec_Pay_Ration  \
# 0                       NaN             NaN          NaN                 NaN
# 1                       NaN             NaN          NaN                 NaN
# 2                       NaN             NaN          NaN                 NaN
# 3                       NaN             NaN          NaN                 NaN
# 4                       NaN             NaN          NaN                 NaN
# ...                     ...             ...          ...                 ...
# 30025              1.478252       -0.003905    -0.040833            0.143513
# 30026              1.478252       -0.003964    -0.040833            0.143513
# 30027              1.478252       -0.003954    -0.040833            0.143513
# 30028              1.478252       -0.003982    -0.040833            0.143513
# 30029                   NaN             NaN          NaN                 NaN
#
#        Earnings_per_stock  15d_Return  30d_Return  60d_Return Stock  \
# 0                     NaN    0.068977    0.159754    0.024331  AAPL
# 1                     NaN    0.072467    0.145100    0.027822  AAPL
# 2                     NaN    0.075065    0.129712    0.050534  AAPL
# 3                     NaN    0.065096    0.111958    0.052262  AAPL
# 4                     NaN    0.058457    0.099345    0.050778  AAPL
# ...                   ...         ...         ...         ...   ...
# 30025           -0.004576         NaN         NaN         NaN   WMT
# 30026           -0.004645         NaN         NaN         NaN   WMT
# 30027           -0.004633         NaN         NaN         NaN   WMT
# 30028           -0.004666         NaN         NaN         NaN   WMT
# 30029                 NaN         NaN         NaN         NaN   WMT
#
#        Percent_from_mth_high        RSI
# 0                   0.090497        NaN
# 1                   0.078382        NaN
# 2                   0.073634        NaN
# 3                   0.061830        NaN
# 4                   0.048195        NaN
# ...                      ...        ...
# 30025               0.021423  50.611591
# 30026               0.036878  45.458196
# 30027               0.034112  46.495166
# 30028               0.041643  44.050466
# 30029               0.036586  46.095222
#
# [30030 rows x 111 columns]

# %% [markdown]
# ## Handle Missing Values

# %%
na_df = dow30.set_index('Date')
na_df = na_df.isna()

# %%
# columns with most NaN values
na_df.sum().sort_values(ascending=False).head(25)

# %%
# dates with most NaN values
na_in_rows = dict()
for date, row in na_df.iterrows():
    na_in_rows[date] = row.sum()

# %%
na_in_rows_df = pd.DataFrame(na_in_rows, index=[0]).stack()

# %%
na_in_rows_df = pd.DataFrame(na_in_rows_df)

# %%
na_in_rows_df.columns = ['#NaN values by date']

# %% [markdown]
# #### Dates before 2020-03-30 have large amounts of missing data due to fundamental data API only giving 3 years historical data, therefore remove dates before then

# %%
na_in_rows_df.loc[na_in_rows_df['#NaN values by date'] != 0].tail(10)

# %%
dow30 = dow30.loc[dow30['Date'] > pd.to_datetime('2020-03-30')]

# %% [markdown]
# #### Find other na patterns

# %%
dow30.isna().sum()

# %% [markdown]
# #### Many missing dividends are due to Salesforce (CRM) not paying a dividend, therefore all of their dividend related features are NaN. Here, keeping these NaN is more appropriate than 0, as these features should not play into the model

# %%
dow30[dow30['dividends_change'].isna()]

# %% [markdown]
# #### Look for source of numerous columns having 79 NaN's

# %%
dow30[dow30['ppeq'].isna()]

# %% [markdown]
# #### Missing values in ppeq column correspond with missing values in most other fundamental metrics, making these NaN values large impact. These missing values are consecutive and occur in April 2020 for a few stocks (Covid?) Therefore, all of these rows can be removed safely.

# %%
dow30 = dow30.loc[~dow30['ppeq'].isna()]

# %% [markdown]
# #### Find source of 2284 missing values in '...Current' and '...NonCurrent' columns

# %%
dow30[dow30['debtNonCurrent'].isna()].tail(50)

# %% [markdown]
# #### Missing values in these columns appear to be consecutive for specific quarters for a few stocks. Due to the small amount of features that are missing in each column, and additionally due to the expected low importance of the missing features, rows will remain in df unchanged.

# %% [markdown]
# #### Trailing PEG1Y appears to be missing for Q3 2021 for a single stock, data will be kept unchanged due to low impact

# %%
dow30.loc[dow30['trailingPEG1Y'].isna()]

# %% [markdown]
# #### shareswaDil column is missing in a sizeable number of consecutive row blocks for various stocks (~1000), but impact is expected to be isolated as it is a single, low importance feature not intersecting with other NaN columns, therefore rows will be kept unchanged.

# %%
dow30.loc[dow30['shareswaDil'].isna()]

# %%
#dow30 = dow30.set_index('level_0')

# %%
dow30_final_with_date = dow30.copy() # Keep finalized version of dow30 df still with datestamps attached (for reference)
dow30_final_with_date
# Out:
#             Date  10YBond  30dBondRet  VIX_high   spy_close  spy_5dret  \
# 267   2020-03-31    0.698   -0.551414     58.75  247.091952   0.060045
# 268   2020-04-01    0.635   -0.595541     60.59  235.971616  -0.002593
# 269   2020-04-02    0.627   -0.588852     57.24  241.416746  -0.035873
# 271        3.318200e+10       0.0   1.437530e+11           9.879300e+10
# ...                 ...       ...            ...                    ...
# 30024      7.794600e+10       0.0   8.768000e+10           0.000000e+00
# 30025      7.794600e+10       0.0   8.768000e+10           0.000000e+00
# 30026      7.794600e+10       0.0   8.768000e+10           0.000000e+00
# 30027      7.794600e+10       0.0   8.768000e+10           0.000000e+00
# 30028      7.794600e+10       0.0   8.768000e+10           0.000000e+00
#
#                debt  debtNonCurrent  liabilitiesNonCurrent  \
# 267    1.095070e+11    8.908600e+10           1.458810e+11
# 268    1.095070e+11    8.908600e+10           1.458810e+11
# 269    1.095070e+11    8.908600e+10           1.458810e+11
# 270    1.095070e+11    8.908600e+10           1.458810e+11
# 271    1.095070e+11    8.908600e+10           1.458810e+11
# ...             ...             ...                    ...
# 30024  6.538000e+10    5.110500e+10           6.612500e+10
# 30025  6.538000e+10    5.110500e+10           6.612500e+10
# 30026  6.538000e+10    5.110500e+10           6.612500e+10
# 30027  6.538000e+10    5.110500e+10           6.612500e+10
# 30028  6.538000e+10    5.110500e+10           6.612500e+10
#
#        liabilitiesCurrent   sharesBasic  longTermDebtEquity  shareFactor  \
# 267          9.609400e+10  1.750192e+10            1.135939          1.0
# 268          9.609400e+10  1.750192e+10            1.135939          1.0
# 269          9.609400e+10  1.750192e+10            1.135939          1.0
# 270          9.609400e+10  1.750192e+10            1.135939          1.0
# 271          9.609400e+10  1.750192e+10            1.135939          1.0
# ...                   ...           ...                 ...          ...
# 30024        1.014080e+11  2.714238e+09            0.707306          1.0
# 30025        1.014080e+11  2.714238e+09            0.707306          1.0
# 30026        1.014080e+11  2.714238e+09            0.707306          1.0
# 30027        1.014080e+11  2.714238e+09            0.707306          1.0
# 30028        1.014080e+11  2.714238e+09            0.707306          1.0
#
#             bookVal       roa  currentRatio       roe  grossMargin  \
# 267    7.842500e+10  0.173146      1.495962  0.644858     0.383619
# 268    7.842500e+10  0.173146      1.495962  0.644858     0.383619
# 269    7.842500e+10  0.173146      1.495962  0.644858     0.383619
# 270    7.842500e+10  0.173146      1.495962  0.644858     0.383619
# 271    7.842500e+10  0.173146      1.495962  0.644858     0.383619
# ...             ...       ...           ...       ...          ...
# 30024  8.012300e+10  0.036383      0.864626  0.115714     0.243435
# 30025  8.012300e+10  0.036383      0.864626  0.115714     0.243435
# 30026  8.012300e+10  0.036383      0.864626  0.115714     0.243435
# 30027  8.012300e+10  0.036383      0.864626  0.115714     0.243435
# 30028  8.012300e+10  0.036383      0.864626  0.115714     0.243435
#
#        piotroskiFScore    epsQoQ  revenueQoQ  profitMargin        rps  \
# 267                6.0  0.035599    0.005137      0.383619   3.331806
# 268                6.0  0.035599    0.005137      0.383619   3.331806
# 269                6.0  0.035599    0.005137      0.383619   3.331806
# 270                6.0  0.035599    0.005137      0.383619   3.331806
# 271                6.0  0.035599    0.005137      0.383619   3.331806
# ...                ...       ...         ...           ...        ...
# 30024              6.0 -1.594595    0.087444      0.243435  56.300517
# 30025              6.0 -1.594595    0.087444      0.243435  56.300517
# 271              0.946208            0.009960    0.061378    0.196205
# ...                   ...                 ...         ...         ...
# 30024            0.143513           -0.004480         NaN         NaN
# 30025            0.143513           -0.004576         NaN         NaN
# 30026            0.143513           -0.004645         NaN         NaN
# 30027            0.143513           -0.004633         NaN         NaN
# 30028            0.143513           -0.004666         NaN         NaN
#
#        60d_Return Stock  Percent_from_mth_high        RSI
# 267      0.438533  AAPL               0.190530  46.016459
# 268      0.471774  AAPL               0.219543  41.996987
# 269      0.480981  AAPL               0.199526  43.591239
# 270      0.515118  AAPL               0.217017  42.489968
# 271      0.390912  AAPL               0.119366  50.540826
# ...           ...   ...                    ...        ...
# 30024         NaN   WMT               0.000000  59.633708
# 30025         NaN   WMT               0.021423  50.611591
# 30026         NaN   WMT               0.036878  45.458196
# 30027         NaN   WMT               0.034112  46.495166
# 30028         NaN   WMT               0.041643  44.050466
#
# [21907 rows x 111 columns]

# %%
#dow30 = dow30.drop(columns=['spy_5dret', 'spy_10dret', 'spy_15dret', 'spy_close'])

# %%
# execute this cell if dow30 needs to have date reinserted
#dow30 = dow30_final_with_date

# %% [markdown]
# #### Keep one sample per business week (1 entry for every 5). Remaining 4/5 will be kept as a final test set. Due to the scope of the model, the minute changes in the features on a day-to-day basis, and the intention for the predictive power to be directed longer term (15d, 30d, 60d, +), keeping all the daily data is unnecessary and will likely cause overfitting quickly

# %%
true_test = dow30.loc[dow30.index % 5 != 0] # large test set
train = dow30.loc[dow30.index % 5 == 0] # smaller train set (yes train set is smaller)
true_test = true_test.loc[true_test['Date'] < pd.to_datetime('2023-01-30')]

# %% [markdown]
# #### Remove zeroes in target to prevent infinite error when using mape

# %%
train = train.loc[~(train['15d_Return'] == 0)]
train = train.loc[~(train['30d_Return'] == 0)]
train = train.loc[~(train['60d_Return'] == 0)]
true_test = true_test.loc[~(true_test['15d_Return'] == 0)]
true_test = true_test.loc[~(true_test['30d_Return'] == 0)]
true_test = true_test.loc[~(true_test['60d_Return'] == 0)]

# %% [markdown]
# #### Split into train and test sets

# %%
x_trn = train.drop(columns=['15d_Return', '30d_Return', '60d_Return'])
x_trn = x_trn.loc[x_trn['Date'] < pd.to_datetime('2023-01-30')]
x_trn = x_trn.drop(columns=['Date'])

y_trn15 = train[['15d_Return','Date']]
y_trn15 = y_trn15.loc[y_trn15['Date'] < pd.to_datetime('2023-01-30')]
y_trn15 = y_trn15.drop(columns=['Date'])

y_trn30 = train[['30d_Return', 'Date']]
y_trn30 = y_trn30.loc[y_trn30['Date'] < pd.to_datetime('2023-01-06')]
y_trn30 = y_trn30.drop(columns=['Date'])

y_trn60 = train[['60d_Return', 'Date']]
y_trn60 = y_trn60.loc[y_trn60['Date'] < pd.to_datetime('2022-11-22')]
y_trn60 = y_trn60.drop(columns=['Date'])

# Must remove date and stock (cat. type) columns before making DMatrix
#dtrain15 = xgb.DMatrix(x_trn, y_trn15)

# %% [markdown]
# # 15 Day Return Prediction

# %%
reg = XGBRegressor()

# %% [markdown]
# #### Perform Grid Search to Optimize Parameters

# %%
# first iteration of grid search params
params = {
    'max_depth'        : range(5, 15, 5),
    'min_child_weight' : range(9, 21, 3),
    'gamma'            : [0.0, 0.5, 1, 10],
    'colsample_bytree' : [0.3, 0.5, 0.7],
    'n_estimators'     : range(10, 70, 20)
    
}
best1 = {
    'colsample_bytree': 0.7,
    'gamma': 0.5,
    'max_depth': 5,
    'min_child_weight': 9,
    'n_estimators': 50
}
bestscore1 = 1.677
# optimal params from first grid search with a range to either side for secondary grid search
params1 = {
    'colsample_bytree' : [0.6, 0.7, 0.8],
    'gamma'            : [0.3, 0.5, 0.7],
    'max_depth'        : range(4, 6, 1),
    'min_child_weight' : range(7, 11, 1),
    'n_estimators'     : range(40, 60, 5)  

}
best2 = {
    'colsample_bytree': 0.8,
    'gamma': 0.5,
    'max_depth': 4,
    'min_child_weight': 7,
    'n_estimators': 45,
}
bestscore2 = 1.6765

# %%
gridp = GridSearchCV(reg, param_grid=params1, n_jobs=-1, scoring='neg_mean_squared_error', cv=5, verbose=3)

# %%
gridp.fit(x_trn, y_trn15)

# %% [markdown]
# #### Evaluate results of Random Search

# %%
print(gridp.best_estimator_)

# %%
pd.DataFrame(gridp.cv_results_).sort_values(by=['rank_test_score'], ascending = True)

# %%
best_first = gridp.best_params_

# %%
opt_paramsp = gridp.best_params_
opt_paramsp

# %% [markdown]
# #### Train model using optimal parameters

# %%
model_cv15 = xgb.cv(opt_paramsp, dtrain15, nfold=5, num_boost_round = 50, metrics='mse', as_pandas=True, early_stopping_rounds=1, shuffle=True)

# %%
model_cv15

# %%
trn_15 = xgb.DMatrix(x_trn, y_trn15)

# %%
tsn_15 = xgb.DMatrix(true_test.drop(columns=['15d_Return', '30d_Return', '60d_Return','Date']), true_test['15d_Return'])

# %%
trainer15 = xgb.train(best2, dtrain15, num_boost_round=30, evals=[(trn_15, 'trnp'), (tsn_15, 'tsnp')], early_stopping_rounds=1)

# %%
with open('model_15.pickle', 'wb') as file:
    pickle.dump(reg15, file)

# %%
with open('model_15.pickle', 'rb') as file:
    trainer15 = pickle.load(file)

# %%
most_recent_test15 = xgb.DMatrix(February_df.drop(columns=['15d_Return', '30d_Return', '60d_Return', 'Date']))

# %% [markdown]
# ## Train model using XGBRegressor object (easier implementation)

# %%
reg15 = XGBRegressor(colsample_bytree=1, gamma=0.0, max_depth=10, min_child_weight=2, 
                     n_estimators=45, early_stopping_rounds=1)

# %% [markdown]
# #### Retrain model excluding Jan 2023 from train set, to have proper comparison

# %%
x_trn = train.loc[train['Date'] < pd.to_datetime('2022-01-01')]
y_trn15 = x_trn.copy()
y_trn15 = y_trn15['15d_Return']
x_trn = x_trn.drop(columns=['Date','Stock','15d_Return','30d_Return', '60d_Return'])
x_tst = dow30.loc[dow30['Date'] > pd.to_datetime('2022-01-01')]
x_tst = x_tst.loc[x_tst['Date'] < pd.to_datetime('2023-01-01')]
y_tst15 = x_tst.copy() 
x_tst = x_tst.drop(columns=['Date','15d_Return', '30d_Return', '60d_Return', 'Stock'])
y_tst15 = y_tst15['15d_Return']

# %%
reg15.fit(x_trn, y_trn15, eval_set=[(x_tst, y_tst15)])
# Out:
# [0]	validation_0-rmse:0.36538
# [1]	validation_0-rmse:0.26777
# [2]	validation_0-rmse:0.20285
# [3]	validation_0-rmse:0.16477
# [4]	validation_0-rmse:0.13774
# [5]	validation_0-rmse:0.12042
# [6]	validation_0-rmse:0.10746
# [7]	validation_0-rmse:0.10067
# [8]	validation_0-rmse:0.09558
# [9]	validation_0-rmse:0.09197
# [10]	validation_0-rmse:0.08959
# [11]	validation_0-rmse:0.08765
# [12]	validation_0-rmse:0.08624
# [13]	validation_0-rmse:0.08586
# [14]	validation_0-rmse:0.08551
# [15]	validation_0-rmse:0.08502
# [16]	validation_0-rmse:0.08480
# [17]	validation_0-rmse:0.08454
# [18]	validation_0-rmse:0.08436
# [19]	validation_0-rmse:0.08432
# [20]	validation_0-rmse:0.08429
# [21]	validation_0-rmse:0.08412
# [22]	validation_0-rmse:0.08404
# [23]	validation_0-rmse:0.08371
# [24]	validation_0-rmse:0.08377
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None, colsample_bytree=1,
#              early_stopping_rounds=1, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.0, gpu_id=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=2, missing=nan, monotone_constraints=None,
#              n_estimators=45, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
preds = reg15.predict(dow30.loc[dow30['Date'] > pd.to_datetime('2022-01-01')].drop(columns=['15d_Return', '30d_Return', '60d_Return','Date', 'Stock']))

# %%
#preds = pd.DataFrame(trainer15.predict(most_recent_test15))

# %%
output15 = dow30.copy()
output15 = output15[['15d_Return','Date']]

output15 = output15.loc[output15['Date'] > pd.to_datetime('2022-01-01')]
output15['Predicted 15d_Return'] = preds

output15['Date'] = output15.index.map(indices_to_dates)
output15['Stock'] = output15.index.map(indices_to_stocks)

output15['Date'] = pd.to_datetime(output15['Date'])
JanFeb_results15 = output15.loc[output15['Date'] > pd.to_datetime('2022-01-01')]

JanFeb_results15 = JanFeb_results15.sort_values(by=['Predicted 15d_Return', 'Date'], ascending=True)

# %%
Jan_results15 = JanFeb_results15.loc[~JanFeb_results15['15d_Return'].isna()]

# %%
JanFeb_results15

# %%
JanFeb_results15[JanFeb_results15['Date'] > pd.to_datetime('2023-02-14')]

# %%
print(mean_absolute_error(Jan_results15['Predicted 15d_Return'], Jan_results15['15d_Return']))
# Out:
# 0.06019836764376099

# %%
# January results from true_test df (model included Jan) achieved 0.03228 mae (+/- 3.2% return on avg)
# January results from train df (model excluded Jan) achieved 0.0521 mae (+/- 5.2% return on avg)
# January results from train df (excluded Jan) achieved 0.04976 mae (after addition of rsi and %from mthly high)

# %%
Jan_results15.sort_values(by=['Predicted 15d_Return'])

# %% [markdown]
# # Profit Analysis

# %% [markdown]
# Model will be assumed to be executed every 2 weeks, where the top n predicted returns on the day of model execution will be purchased. Then, two weeks later, the positions will be exited, and positions for the n highest predicted returns on that day will be entered. Profit will be averaged by switching the day of model execution (Every other monday->Every other tuesday..etc). An overall avg profit will then be developed using this specific execution strategy. Further optimization work or even a future ML model can tackle the optimal number of n stocks to divide the allocation amongst as well as any staggerred position entry/exit.

# %%
profit_analysis15 = Jan_results15.sort_values('Date')

profit_analysis15
# Out:
#        15d_Return       Date  Predicted 15d_Return Stock
# 711     -0.122136 2022-01-03             -0.040589  AAPL
# 1712    -0.007279 2022-01-03              0.043935  AMGN
# 24735    0.082504 2022-01-03              0.010904   TRV
# 27738    0.020675 2022-01-03              0.000810    VZ
# 23734   -0.015368 2022-01-03              0.040646    PG
# ...           ...        ...                   ...   ...
# 25008    0.014062 2023-02-03              0.040656   TRV
# 26009    0.023940 2023-02-03              0.018023   UNH
# 27010   -0.040619 2023-02-03             -0.040407     V
# 13997   -0.035346 2023-02-03             -0.022738   IBM
# 30013   -0.001905 2023-02-03              0.016117   WMT
#
# [8220 rows x 4 columns]

# %% [markdown]
# Add 1-14d returns as columns, to aid in prediction and loss-stopping. A future model may be trained on this dataset to suggest changes to positions after entry.

# %%
for i in range(1, 11):
    profit_analysis15['%sd_Return'%(i)] = profit_analysis15.index + i
    profit_analysis15['%sd_Return'%(i)] = (profit_analysis15['%sd_Return'%(i)].map(price_mapping) - profit_analysis15.index.map(price_mapping)) /  profit_analysis15.index.map(price_mapping)

    profit_analysis15

# divide profit_analysis15 into results for each day of the business week
pa15mon = profit_analysis15.loc[profit_analysis15['Date'].dt.dayofweek == 0]
pa15tues = profit_analysis15.loc[profit_analysis15['Date'].dt.dayofweek == 1]
pa15wed = profit_analysis15.loc[profit_analysis15['Date'].dt.dayofweek == 2]
pa15th = profit_analysis15.loc[profit_analysis15['Date'].dt.dayofweek == 3]
pa15fri = profit_analysis15.loc[profit_analysis15['Date'].dt.dayofweek == 4]

pa15mon = pa15mon.sort_values(by=['Date', 'Predicted 15d_Return'], ascending=True)
pa15tues = pa15tues.sort_values(by=['Date', 'Predicted 15d_Return'], ascending=True)
pa15wed = pa15wed.sort_values(by=['Date', 'Predicted 15d_Return'], ascending=True)
pa15th = pa15th.sort_values(by=['Date', 'Predicted 15d_Return'], ascending=True)
pa15fri = pa15fri.sort_values(by=['Date', 'Predicted 15d_Return'], ascending=True)

# %%
profits15 = pd.DataFrame(columns=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], index=range(1,10))

# loop over number of stocks to split positions in each entry, and see which yields best profit
for i in range(1, 10):
    mon = pd.DataFrame(pa15mon.groupby('Date')['Predicted 15d_Return'].nlargest(i)).reset_index().set_index('level_1')
    mon['Stock'] = mon.index.map(indices_to_stocks)
    mon['15d_Return'] = mon.index.map(act_returns_mapping15)
    weeks_mon = mon.groupby('Date')['15d_Return'].mean()
    profits15['Monday'].loc[i] = weeks_mon.mean()
    
    tues = pd.DataFrame(pa15tues.groupby('Date')['Predicted 15d_Return'].nlargest(i)).reset_index().set_index('level_1')
    tues['Stock'] = tues.index.map(indices_to_stocks)
    tues['15d_Return'] = tues.index.map(act_returns_mapping15)
    weeks_tues = tues.groupby('Date')['15d_Return'].mean()
    profits15['Tuesday'].loc[i] = weeks_tues.mean()

    wed = pd.DataFrame(pa15wed.groupby('Date')['Predicted 15d_Return'].nlargest(i)).reset_index().set_index('level_1')
    wed['Stock'] = wed.index.map(indices_to_stocks)
    wed['15d_Return'] = wed.index.map(act_returns_mapping15)
    weeks_wed = wed.groupby('Date')['15d_Return'].mean()
    profits15['Wednesday'].loc[i] = weeks_wed.mean()

    th = pd.DataFrame(pa15th.groupby('Date')['Predicted 15d_Return'].nlargest(i)).reset_index().set_index('level_1')
    th['Stock'] = th.index.map(indices_to_stocks)
    th['15d_Return'] = th.index.map(act_returns_mapping15)
    weeks_th = th.groupby('Date')['15d_Return'].mean()
    profits15['Thursday'].loc[i] = weeks_th.mean()

    fri = pd.DataFrame(pa15fri.groupby('Date')['Predicted 15d_Return'].nlargest(i)).reset_index().set_index('level_1')
    fri['Stock'] = fri.index.map(indices_to_stocks)
    fri['15d_Return'] = fri.index.map(act_returns_mapping15)
    weeks_fri = fri.groupby('Date')['15d_Return'].mean()
    profits15['Friday'].loc[i] = weeks_fri.mean()

# %%
profits15 # shows mean return for entering positions in stocks with the n highest predicted returns on the specified weekday
# over a 15d holding period
# Out:
#      Monday   Tuesday Wednesday  Thursday    Friday
# 1   0.03658  0.039558  0.046356  0.047609  0.021667
# 2  0.032667  0.037756  0.032586   0.03263  0.020711
# 3  0.029626  0.033507  0.031702   0.03051  0.022964
# 4  0.025685  0.027601   0.02934  0.028662  0.022034
# 5  0.022656  0.024148  0.028336  0.027062  0.023074
# 6  0.022888  0.022841   0.02535  0.025396  0.022418
# 7  0.020197   0.02412  0.022773  0.023017   0.01995
# 8  0.019264  0.024011  0.020751  0.020681  0.019246
# 9  0.017865  0.023159  0.019913  0.018714  0.018177

# %%
# maximum profit: 2 stocks on every third tuesday
tues = pd.DataFrame(pa15tues.groupby('Date')['Predicted 15d_Return'].nlargest(1)).reset_index()
tues['Stock'] = tues['level_1'].map(indices_to_stocks)
tues['15d_Return'] = tues['level_1'].map(act_returns_mapping15)
tues1 = tues.loc[(tues.index % 6 == 2) | (tues.index % 6 == 3)] # Takes the two stocks every third tuesday

# %%
for i in range(1, 11):
    tues['%sd_Return'%(i)] = tues['level_1'] + i
    tues['%sd_Return'%(i)] = (tues['%sd_Return'%(i)].map(price_mapping) - tues['level_1'].map(price_mapping)) /  tues['level_1'].map(price_mapping)

# %%
tues[tues['Date'].dt.month==9]
# Out:
#          Date  level_1  Predicted 15d_Return Stock  15d_Return  1d_Return  \
# 35 2022-09-06    19880              0.108696   MMM   -0.035935   0.033877
# 36 2022-09-13    19885              0.107198   MMM   -0.040259  -0.024404
# 37 2022-09-20    19890              0.162543   MMM   -0.065911  -0.014676
# 38 2022-09-27    27895              0.167077    VZ   -0.030362   0.012857
#
#     2d_Return  3d_Return  4d_Return  5d_Return  6d_Return  7d_Return  \
# 35   0.022899   0.055746   0.065609   0.033190   0.007976  -0.001544
# 36  -0.033618  -0.032041  -0.031792  -0.032788  -0.046983  -0.052544
# 37  -0.020426  -0.030295  -0.030209  -0.035273  -0.019224  -0.036217
# 38  -0.006428  -0.023656   0.006943   0.023656   0.013114  -0.010221
#
#     8d_Return  9d_Return  10d_Return
# 35   0.000086   0.000343   -0.000686
# 36  -0.062090  -0.062007   -0.066905
# 37  -0.051665  -0.028321   -0.007724
# 38  -0.036117  -0.042133   -0.059919

# %%
mae = tues1.groupby('Date')['15d_Return'].mean()
funds = 1
for week in mae:
    funds *= (1+week)
funds
# Out:
# 2.0733962846955087

# %% [markdown]
# #### 1.702999x initial investment starting first tuesday of the year, 1.285x for second tuesday, 2.722x starting third tuesday. To balance these out, a 2-stock purchase every tuesday, with a 1/6 allocation to each position is suggested

# %% [markdown]
# ### With 2-stock buy/sell each tuesday with 1/3 allocation on each day, we achieve a 1.925x initial investment return over a year

# %%
tues_cleaned = tues # run for no interference trading, run line below for avoiding trading 
#tues_cleaned = tues.loc[(tues['Date'] < pd.to_datetime('2022-08-15')) | (tues['Date'] > pd.to_datetime('2022-09-25'))]
funds = 0
alloc = 1.0/6.0
all1, all2, all3, all4, all5, all6 = alloc, alloc, alloc, alloc, alloc, alloc
for num, ret in enumerate(tues_cleaned['15d_Return']):
    n = num % 6
    if n == 0:
        all1 *= (1+ret)
    elif n == 1:
        all2 *= (1+ret)
    elif n == 2:
        all3 *= (1+ret)
    elif n == 3:
        all4 *= (1+ret)
    elif n == 4:
        all5 *= (1+ret)
    else:
        all6 *= (1+ret)
funds = all1 + all2 + all3 + all4 + all5 + all6
print('If early exit is not allowed, Multiplier at the end of the year is: %sx'%(funds))
# Out:
# If early exit is not allowed, Multiplier at the end of the year is: 1.6545717512111993x

# %%
# for nlargest(1)
tues_cleaned = tues # run for no interference trading, run line below for avoiding trading 
#tues_cleaned = tues.loc[(tues['Date'] < pd.to_datetime('2022-08-15')) | (tues['Date'] > pd.to_datetime('2022-09-25'))]
funds = 0
alloc = 1.0/3.0
all1, all2, all3= alloc, alloc, alloc
for num, ret in enumerate(tues_cleaned['15d_Return']):
    n = num % 3
    if n == 0:
        all1 *= (1+ret)
    elif n == 1:
        all2 *= (1+ret)
    else:
        all3 *= (1+ret)
funds = all1 + all2 + all3 
print('If early exit is not allowed, Multiplier at the end of the year is: %sx'%(funds))
# Out:
# If early exit is not allowed, Multiplier at the end of the year is: 2.0344904212269506x

# %%
tues[tues['15d_Return'] < 0]['15d_Return'].mean()
# Out:
# -0.04102481328105927

# %% [markdown]
# ### Try a stop loss or gain trigger rule (if x% of predicted return is realized on day n, exit position on day n and do not reinvest those funds until the full 15day period is over, regardless of n

# %%
funds = 0
alloc = 1.0/6.0
all1, all2, all3, all4, all5, all6 = alloc, alloc, alloc, alloc, alloc, alloc
thresh = 2.5
for i, row in tues.iterrows():
    ret = row['15d_Return']
    for n in range(1, 10):
        if (row['%sd_Return'%(n)] > (thresh * row['Predicted 15d_Return'])):
            ret = row['%sd_Return'%(n)]
            break
    j = i % 6
    if j == 0:
        all1 *= (1+ret)
    elif j == 1:
        all2 *= (1+ret)
    elif j == 2:
        all3 *= (1+ret)
    elif j == 3:
        all4 *= (1+ret)
    elif j == 4:
        all5 *= (1+ret)
    else:
        all6 *= (1+ret)      
funds = all1 + all2 + all3 + all4 + all5 + all6
print(f'Multiplier at the end of the year using {thresh}x return threshold for early exit:{funds}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1d_Return'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [89], in <cell line: 5>()
#       6 ret = row['15d_Return']
#       7 for n in range(1, 10):
# ----> 8     if (row['%sd_Return'%(n)] > (thresh * row['Predicted 15d_Return'])):
#       9         ret = row['%sd_Return'%(n)]
#      10         break
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '1d_Return'

# %% [markdown]
# #### Percentage Accuracy: measured as percentage of top 2 predicted returns that yield a return > r%

# %%
for r in range(0, 9):
    perc = len(tues.loc[tues['15d_Return'] > (r * 0.01)]) / len(tues)
    print(f'percentage of actual returns greater than{r}% is:{perc*100}%')
# Out:
# percentage of actual returns greater than0% is:64.91228070175438%
# percentage of actual returns greater than1% is:61.40350877192983%
# percentage of actual returns greater than2% is:57.89473684210527%
# percentage of actual returns greater than3% is:56.14035087719298%
# percentage of actual returns greater than4% is:54.385964912280706%
# percentage of actual returns greater than5% is:49.122807017543856%
# percentage of actual returns greater than6% is:47.368421052631575%
# percentage of actual returns greater than7% is:40.35087719298245%
# percentage of actual returns greater than8% is:36.84210526315789%

# %% [markdown]
# #### Percentage Accuracy for nlargest = (choice) for all days

# %%
choice = 1
week = pd.DataFrame(profit_analysis15.groupby('Date')['Predicted 15d_Return'].nlargest(choice)).reset_index()
week['Stock'] = week['level_1'].map(indices_to_stocks)
week['15d_Return'] = week['level_1'].map(act_returns_mapping15)
for i in range(1, 11):
    week['%sd_Return'%(i)] = week['level_1'] + i
    week['%sd_Return'%(i)] = (week['%sd_Return'%(i)].map(price_mapping) - week['level_1'].map(price_mapping)) /  week['level_1'].map(price_mapping)

# %%
for r in range(0, 15):
    perc = len(week.loc[week['15d_Return'] > (r * 0.01)]) / len(week)
    print(f'percentage of actual returns greater than {r}% is:{perc*100}%')
# Out:
# percentage of actual returns greater than 0% is:64.23357664233576%
# percentage of actual returns greater than 1% is:59.12408759124088%
# percentage of actual returns greater than 2% is:56.56934306569343%
# percentage of actual returns greater than 3% is:53.284671532846716%
# percentage of actual returns greater than 4% is:49.63503649635037%
# percentage of actual returns greater than 5% is:46.715328467153284%
# percentage of actual returns greater than 6% is:43.06569343065693%
# percentage of actual returns greater than 7% is:37.591240875912405%
# percentage of actual returns greater than 8% is:33.21167883211679%
# percentage of actual returns greater than 9% is:30.29197080291971%
# percentage of actual returns greater than 10% is:25.91240875912409%
# percentage of actual returns greater than 11% is:23.722627737226276%
# percentage of actual returns greater than 12% is:21.16788321167883%
# percentage of actual returns greater than 13% is:18.248175182481752%
# percentage of actual returns greater than 14% is:15.693430656934307%

# %% [markdown]
# ### Percentage Accuracy for each month after train-test boundary (does accuracy decrease over time)

# %% [markdown]
# #### results show little to no discernable correlation with time after train-test boundary, but indicates a huge reliance on market factors- accuracy for correct >0% return prediction as low as 23% in Sept2022, and as high as 95% for Oct2022

# %%
week2 = week[week['Date'].dt.year == 2022]
for mth in range(1, 13):
    mthloop = week2[week2['Date'].dt.month == mth]
    for r in range(0, 10):
        perc = len(mthloop.loc[mthloop['15d_Return'] > ((r * 0.1)*mthloop['Predicted 15d_Return'])]) / len(mthloop)
        print(f'percentage of actual returns greater than {r*10}% of prediction in month {mth}is:{perc*100}%')
    print('----------------------------------------------------------')
# Out:
# percentage of actual returns greater than 0% of prediction in month 1is:75.0%
# percentage of actual returns greater than 10% of prediction in month 1is:70.0%
# percentage of actual returns greater than 20% of prediction in month 1is:65.0%
# percentage of actual returns greater than 30% of prediction in month 1is:65.0%
# percentage of actual returns greater than 40% of prediction in month 1is:45.0%
# percentage of actual returns greater than 50% of prediction in month 1is:25.0%
# percentage of actual returns greater than 60% of prediction in month 1is:25.0%
# percentage of actual returns greater than 70% of prediction in month 1is:25.0%
# percentage of actual returns greater than 80% of prediction in month 1is:20.0%
# percentage of actual returns greater than 90% of prediction in month 1is:15.0%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 2is:57.89473684210527%
# percentage of actual returns greater than 10% of prediction in month 2is:57.89473684210527%
# percentage of actual returns greater than 20% of prediction in month 2is:52.63157894736842%
# percentage of actual returns greater than 30% of prediction in month 2is:47.368421052631575%
# percentage of actual returns greater than 40% of prediction in month 2is:42.10526315789473%
# percentage of actual returns greater than 50% of prediction in month 2is:36.84210526315789%
# percentage of actual returns greater than 60% of prediction in month 2is:36.84210526315789%
# percentage of actual returns greater than 70% of prediction in month 2is:21.052631578947366%
# percentage of actual returns greater than 80% of prediction in month 2is:15.789473684210526%
# percentage of actual returns greater than 90% of prediction in month 2is:15.789473684210526%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 3is:82.6086956521739%
# percentage of actual returns greater than 10% of prediction in month 3is:78.26086956521739%
# percentage of actual returns greater than 20% of prediction in month 3is:73.91304347826086%
# percentage of actual returns greater than 30% of prediction in month 3is:73.91304347826086%
# percentage of actual returns greater than 40% of prediction in month 3is:73.91304347826086%
# percentage of actual returns greater than 50% of prediction in month 3is:73.91304347826086%
# percentage of actual returns greater than 60% of prediction in month 3is:73.91304347826086%
# percentage of actual returns greater than 70% of prediction in month 3is:69.56521739130434%
# percentage of actual returns greater than 80% of prediction in month 3is:47.82608695652174%
# percentage of actual returns greater than 90% of prediction in month 3is:39.130434782608695%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 4is:20.0%
# percentage of actual returns greater than 10% of prediction in month 4is:20.0%
# percentage of actual returns greater than 20% of prediction in month 4is:20.0%
# percentage of actual returns greater than 30% of prediction in month 4is:15.0%
# percentage of actual returns greater than 40% of prediction in month 4is:15.0%
# percentage of actual returns greater than 50% of prediction in month 4is:15.0%
# percentage of actual returns greater than 60% of prediction in month 4is:10.0%
# percentage of actual returns greater than 70% of prediction in month 4is:10.0%
# percentage of actual returns greater than 80% of prediction in month 4is:10.0%
# percentage of actual returns greater than 90% of prediction in month 4is:10.0%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 5is:76.19047619047619%
# percentage of actual returns greater than 10% of prediction in month 5is:66.66666666666666%
# percentage of actual returns greater than 20% of prediction in month 5is:52.38095238095239%
# percentage of actual returns greater than 30% of prediction in month 5is:47.61904761904761%
# percentage of actual returns greater than 40% of prediction in month 5is:38.095238095238095%
# percentage of actual returns greater than 50% of prediction in month 5is:33.33333333333333%
# percentage of actual returns greater than 60% of prediction in month 5is:19.047619047619047%
# percentage of actual returns greater than 70% of prediction in month 5is:14.285714285714285%
# percentage of actual returns greater than 80% of prediction in month 5is:9.523809523809524%
# percentage of actual returns greater than 90% of prediction in month 5is:0.0%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 6is:33.33333333333333%
# percentage of actual returns greater than 10% of prediction in month 6is:19.047619047619047%
# percentage of actual returns greater than 20% of prediction in month 6is:19.047619047619047%
# percentage of actual returns greater than 30% of prediction in month 6is:19.047619047619047%
# percentage of actual returns greater than 40% of prediction in month 6is:14.285714285714285%
# percentage of actual returns greater than 50% of prediction in month 6is:14.285714285714285%
# percentage of actual returns greater than 60% of prediction in month 6is:14.285714285714285%
# percentage of actual returns greater than 70% of prediction in month 6is:14.285714285714285%
# percentage of actual returns greater than 80% of prediction in month 6is:14.285714285714285%
# percentage of actual returns greater than 90% of prediction in month 6is:9.523809523809524%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 7is:95.0%
# percentage of actual returns greater than 10% of prediction in month 7is:95.0%
# percentage of actual returns greater than 20% of prediction in month 7is:95.0%
# percentage of actual returns greater than 30% of prediction in month 7is:95.0%
# percentage of actual returns greater than 40% of prediction in month 7is:95.0%
# percentage of actual returns greater than 50% of prediction in month 7is:85.0%
# percentage of actual returns greater than 60% of prediction in month 7is:75.0%
# percentage of actual returns greater than 70% of prediction in month 7is:50.0%
# percentage of actual returns greater than 80% of prediction in month 7is:40.0%
# percentage of actual returns greater than 90% of prediction in month 7is:35.0%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 8is:47.82608695652174%
# percentage of actual returns greater than 10% of prediction in month 8is:39.130434782608695%
# percentage of actual returns greater than 20% of prediction in month 8is:34.78260869565217%
# percentage of actual returns greater than 30% of prediction in month 8is:26.08695652173913%
# percentage of actual returns greater than 40% of prediction in month 8is:21.73913043478261%
# percentage of actual returns greater than 50% of prediction in month 8is:21.73913043478261%
# percentage of actual returns greater than 60% of prediction in month 8is:17.391304347826086%
# percentage of actual returns greater than 70% of prediction in month 8is:8.695652173913043%
# percentage of actual returns greater than 80% of prediction in month 8is:4.3478260869565215%
# percentage of actual returns greater than 90% of prediction in month 8is:0.0%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 9is:14.285714285714285%
# percentage of actual returns greater than 10% of prediction in month 9is:9.523809523809524%
# percentage of actual returns greater than 20% of prediction in month 9is:4.761904761904762%
# percentage of actual returns greater than 30% of prediction in month 9is:4.761904761904762%
# percentage of actual returns greater than 40% of prediction in month 9is:4.761904761904762%
# percentage of actual returns greater than 50% of prediction in month 9is:4.761904761904762%
# percentage of actual returns greater than 60% of prediction in month 9is:4.761904761904762%
# percentage of actual returns greater than 70% of prediction in month 9is:4.761904761904762%
# percentage of actual returns greater than 80% of prediction in month 9is:0.0%
# percentage of actual returns greater than 90% of prediction in month 9is:0.0%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 10is:100.0%
# percentage of actual returns greater than 10% of prediction in month 10is:100.0%
# percentage of actual returns greater than 20% of prediction in month 10is:100.0%
# percentage of actual returns greater than 30% of prediction in month 10is:95.23809523809523%
# percentage of actual returns greater than 40% of prediction in month 10is:90.47619047619048%
# percentage of actual returns greater than 50% of prediction in month 10is:80.95238095238095%
# percentage of actual returns greater than 60% of prediction in month 10is:71.42857142857143%
# percentage of actual returns greater than 70% of prediction in month 10is:66.66666666666666%
# percentage of actual returns greater than 80% of prediction in month 10is:66.66666666666666%
# percentage of actual returns greater than 90% of prediction in month 10is:52.38095238095239%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 11is:52.38095238095239%
# percentage of actual returns greater than 10% of prediction in month 11is:52.38095238095239%
# percentage of actual returns greater than 20% of prediction in month 11is:38.095238095238095%
# percentage of actual returns greater than 30% of prediction in month 11is:38.095238095238095%
# percentage of actual returns greater than 40% of prediction in month 11is:38.095238095238095%
# percentage of actual returns greater than 50% of prediction in month 11is:38.095238095238095%
# percentage of actual returns greater than 60% of prediction in month 11is:38.095238095238095%
# percentage of actual returns greater than 70% of prediction in month 11is:38.095238095238095%
# percentage of actual returns greater than 80% of prediction in month 11is:38.095238095238095%
# percentage of actual returns greater than 90% of prediction in month 11is:38.095238095238095%
# ----------------------------------------------------------
# percentage of actual returns greater than 0% of prediction in month 12is:90.47619047619048%
# percentage of actual returns greater than 10% of prediction in month 12is:90.47619047619048%
# percentage of actual returns greater than 20% of prediction in month 12is:85.71428571428571%
# percentage of actual returns greater than 30% of prediction in month 12is:71.42857142857143%
# percentage of actual returns greater than 40% of prediction in month 12is:66.66666666666666%
# percentage of actual returns greater than 50% of prediction in month 12is:66.66666666666666%
# percentage of actual returns greater than 60% of prediction in month 12is:57.14285714285714%
# percentage of actual returns greater than 70% of prediction in month 12is:47.61904761904761%
# percentage of actual returns greater than 80% of prediction in month 12is:47.61904761904761%
# percentage of actual returns greater than 90% of prediction in month 12is:47.61904761904761%
# ----------------------------------------------------------

# %%
tues
# Out:
#          Date  level_1  Predicted 15d_Return Stock  15d_Return  1d_Return  \
# 0  2022-01-04     7712              0.096276   CVX    0.092728   0.006506
# 1  2022-01-11    24717              0.044199   TRV    0.058593  -0.001165
# 2  2022-01-18    10721              0.123016    GS    0.044300  -0.019977
# 3  2022-01-25    10726              0.156443    GS    0.065554   0.003308
# 4  2022-02-01     7731              0.057401   CVX    0.016275   0.004600
# 5  2022-02-08    20736              0.090878   MRK   -0.003121  -0.004941
# 6  2022-02-15    10741              0.059556    GS   -0.077807  -0.010689
# 7  2022-02-22    11745              0.112673    HD    0.045349  -0.024417
# 8  2022-03-01     7750              0.117009   CVX    0.095979   0.029522
# 42   0.169421   0.173322    0.179481
# 43   0.237899   0.210420    0.222974
# 44   0.124480   0.107520    0.130347
# 45   0.001885  -0.008585    0.024709
# 46  -0.002910  -0.040744   -0.042199
# 47  -0.001722   0.026452    0.019038
# 48  -0.018345  -0.045214   -0.043732
# 49  -0.070644  -0.087962   -0.111193
# 50   0.150567   0.174402    0.168685
# 51   0.054650   0.065796    0.074031
# 52   0.109289   0.101573    0.079166
# 53   0.013158   0.021908    0.031382
# 54   0.120715   0.122992    0.137756
# 55   0.151484   0.136162    0.150454
# 56  -0.010428   0.001738   -0.007560

# %% [markdown]
# # 15d Run for use

# %%
reg15 = XGBRegressor(colsample_bytree=0.9, gamma=0.0, max_depth=10, min_child_weight=1, 
                     n_estimators=45, early_stopping_rounds=1)

# %% [markdown]
# ### Forward fill last day or two of fundamental data if needed

# %%
# make predictions df, with any NaN values forward filled from previous day in the vicinity
dow30_lastdays = dow30orig.loc[dow30orig['Date'] > pd.to_datetime('2023-02-26')] 
dow30_lastdays.ffill(axis=0, inplace=True)

x_trn = train.loc[train['Date'] < pd.to_datetime('2022-01-01')]
y_trn15 = x_trn.copy()
y_trn15 = y_trn15['15d_Return']
x_trn = x_trn.drop(columns=['Date','Stock','15d_Return','30d_Return', '60d_Return'])
x_tst = dow30.loc[dow30['Date'] > pd.to_datetime('2022-01-01')]
x_tst = x_tst.loc[x_tst['Date'] < pd.to_datetime('2023-01-01')]
y_tst15 = x_tst.copy() 
x_tst = x_tst.drop(columns=['Date','15d_Return', '30d_Return', '60d_Return', 'Stock'])
y_tst15 = y_tst15['15d_Return']

dow30_lastdays

# %%
reg15.fit(x_trn, y_trn15, eval_set=[(x_tst, y_tst15)])
# Out:
# [0]	validation_0-rmse:0.36554
# [1]	validation_0-rmse:0.26768
# [2]	validation_0-rmse:0.20265
# [3]	validation_0-rmse:0.16059
# [4]	validation_0-rmse:0.13363
# [5]	validation_0-rmse:0.11610
# [6]	validation_0-rmse:0.10268
# [7]	validation_0-rmse:0.09496
# [8]	validation_0-rmse:0.09029
# [9]	validation_0-rmse:0.08658
# [10]	validation_0-rmse:0.08402
# [11]	validation_0-rmse:0.08263
# [12]	validation_0-rmse:0.08168
# [13]	validation_0-rmse:0.08099
# [14]	validation_0-rmse:0.08036
# [15]	validation_0-rmse:0.07981
# [16]	validation_0-rmse:0.07963
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, early_stopping_rounds=1,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.0, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=45, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
with open('reg_15.pickle', 'wb') as file:
    pickle.dump(reg15, file)

# %%
with open('reg_15.pickle', 'rb') as file:
    reg15 = pickle.load(file)

# %%
preds = reg15.predict(dow30_lastdays.drop(columns=['15d_Return', '30d_Return', '60d_Return','Date', 'Stock']))

# %%
#preds = pd.DataFrame(trainer15.predict(most_recent_test15))

# %%
Predictions = dow30_lastdays.copy()
Predictions = Predictions[['15d_Return','Date']]
Predictions['Predicted 15d_Return'] = preds
Predictions['Date'] = Predictions.index.map(indices_to_dates)
Predictions['Stock'] = Predictions.index.map(indices_to_stocks)
Predictions['Date'] = pd.to_datetime(Predictions['Date'])
Results = Predictions.sort_values(by=['Predicted 15d_Return', 'Date'], ascending=False)
Results
# Out:
#        15d_Return       Date  Predicted 15d_Return Stock
# 28026         NaN 2023-02-27              0.134321    VZ
# 9007          NaN 2023-02-27              0.128076   DIS
# 15013         NaN 2023-02-27              0.115284  INTC
# 28027         NaN 2023-02-28              0.113328    VZ
# 15014         NaN 2023-02-28              0.105826  INTC
# 12010         NaN 2023-02-27              0.104545    HD
# 12011         NaN 2023-02-28              0.103801    HD
# 8007          NaN 2023-02-28              0.094964   CVX
# 9008          NaN 2023-02-28              0.094359   DIS
# 22021         NaN 2023-02-28              0.090800  MSFT
# 16015         NaN 2023-02-28              0.083621   JNJ
# 8006          NaN 2023-02-27              0.082556   CVX
# 20019         NaN 2023-02-28              0.081757   MMM
# 23022         NaN 2023-02-28              0.076366   NKE
# 20018         NaN 2023-02-27              0.074307   MMM
# 16014         NaN 2023-02-27              0.072956   JNJ
# 22020         NaN 2023-02-27              0.068168  MSFT
# 13011         NaN 2023-02-27              0.066056   HON
# 13012         NaN 2023-02-28              0.063453   HON
# 4003          NaN 2023-02-28              0.063169    BA
# 23021         NaN 2023-02-27              0.059952   NKE
# 11010         NaN 2023-02-28              0.057082    GS
# 24023         NaN 2023-02-28              0.055122    PG
# 24022         NaN 2023-02-27              0.052739    PG
# 21020         NaN 2023-02-28              0.051835   MRK
# 1000          NaN 2023-02-28              0.048625  AAPL
# 7005          NaN 2023-02-27              0.047652  CSCO
# 10008         NaN 2023-02-27              0.046461   DOW
# 25023         NaN 2023-02-27              0.045690   TRV
# 999           NaN 2023-02-27              0.044049  AAPL
# 25024         NaN 2023-02-28              0.041682   TRV
# 30028         NaN 2023-02-27              0.039478   WMT
# 18017         NaN 2023-02-28              0.038950    KO
# 10009         NaN 2023-02-28              0.038824   DOW
# 4002          NaN 2023-02-27              0.037050    BA
# 3002          NaN 2023-02-28              0.034138   AXP
# 29028         NaN 2023-02-28              0.033679   WBA
# 27025         NaN 2023-02-27              0.033598     V
# 7006          NaN 2023-02-28              0.032533  CSCO
# 30029         NaN 2023-02-28              0.032271   WMT
# 14013         NaN 2023-02-28              0.030959   IBM
# 26025         NaN 2023-02-28              0.030936   UNH
# 5003          NaN 2023-02-27              0.029960   CAT
# 19018         NaN 2023-02-28              0.029561   MCD
# 27026         NaN 2023-02-28              0.029348     V
# 6004          NaN 2023-02-27              0.028049   CRM
# 17015         NaN 2023-02-27              0.027888   JPM
# 29027         NaN 2023-02-27              0.027760   WBA
# 6005          NaN 2023-02-28              0.027414   CRM
# 2001          NaN 2023-02-28              0.025723  AMGN
# 5004          NaN 2023-02-28              0.025710   CAT
# 3001          NaN 2023-02-27              0.022057   AXP
# 26024         NaN 2023-02-27              0.021402   UNH
# 18016         NaN 2023-02-27              0.021304    KO
# 19017         NaN 2023-02-27              0.013725   MCD
# 11009         NaN 2023-02-27              0.003340    GS
# 14012         NaN 2023-02-27             -0.000020   IBM
# 21019         NaN 2023-02-27             -0.001238   MRK
# 17016         NaN 2023-02-28             -0.006783   JPM
# 2000          NaN 2023-02-27             -0.021206  AMGN

# %% [markdown]
# ## Neural Network Alternative to XGBoost

# %%
sc = StandardScaler()
x_trnfs = sc.fit_transform(x_trn)
y_trn15fs = sc.fit_transform(np.array(y_trn15).reshape(-1,1))
x_tstfs = sc.fit_transform(x_tst)
y_tst15fs = sc.fit_transform(np.array(y_tst15).reshape(-1,1))

# %%
model=Sequential()
model.add(Dense(106, input_shape=(106,1)))
model.add(Dense(72))
model.add(Dense(36))
model.add(Dense(20))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')
#model.add(Conv1D(filters=24, kernel_size=1, padding='same', activation='tanh',input_shape=(1, 6)))
#model.add(MaxPooling1D(pool_size=1, padding='same'))
#model.add(LSTM(24, activation='tanh'))

model.fit(x=x_trnfs, y=y_trn15fs, validation_data=(x_tstfs,y_tst15fs), epochs=100,verbose=1, callbacks=[EarlyStopping(monitor='val_loss', patience=2)])
name = '15d'+'_model.pickle'
with open(name, 'wb') as file:
    pickle.dump(model, file)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 3s 101ms/step - loss: nan - val_loss: nan
# Epoch 2/100
# 21/21 [==============================] - 2s 104ms/step - loss: nan - val_loss: nan
# INFO:tensorflow:Assets written to: ram://0975f93e-989f-440f-a053-15e8bd0ee268/assets

# %%
pd.DataFrame(y_tst15fs).isna().sum()
# Out:
# 0    0
# dtype: int64

# %%
x_trn.isna().sum().sum()
# Out:
# 3649

# %%
pd.DataFrame(x_trnfs).isna().sum().sum()
# Out:
# 3649

# %% [markdown]
# ## Profit Analysis based on Stock

# %%
by_stock = profit_analysis15.groupby('Stock')['Predicted 15d_Return', '15d_Return'].mean()

# %%
by_stock['Mean_abs_error'] = abs(by_stock['Predicted 15d_Return'] - by_stock['15d_Return'])

# %%
by_stock.sort_values(by=['Mean_abs_error'], ascending=True)

# %% [markdown]
# #### Now compute mae for predictions above a 5% Predicted Return threshold

# %%
by_stock_top = profit_analysis15.loc[profit_analysis15['Predicted 15d_Return'] > 0.05].groupby('Stock')['Predicted 15d_Return', '15d_Return'].mean()

# %%
by_stock_top['Mean_abs_error'] = abs(by_stock_top['Predicted 15d_Return'] - by_stock_top['15d_Return'])

# %%
by_stock_top.sort_values(by=['Mean_abs_error'], ascending=True)

# %% [markdown]
# ### Feature importances

# %%
importances15 = pd.DataFrame(reg15.get_booster().get_score(importance_type='gain'), index=[0]).transpose()
importances15.columns = ['gain']
#importances15 = pd.DataFrame(reg15.get_booster().get_score(importance_type='weight'), index=[0]).transpose()
#importances15.columns = ['weight']

# %%
importances15.sort_values(by=['gain'], ascending = False)
#importances15.sort_values(by=['weight'], ascending = False)

# %% [markdown]
# # 30 Day Return Prediction

# %% [markdown]
# #### Retrain model excluding Jan 2023 from train set, to have proper comparison

# %%
reg30 = XGBRegressor(colsample_bytree=1, gamma=0.0, max_depth=10, min_child_weight=2, 
                     n_estimators=45, early_stopping_rounds=1)

# %%
x_trn = train.loc[train['Date'] < pd.to_datetime('2022-01-01')]
y_trn30 = x_trn.copy()
y_trn30 = y_trn30['30d_Return']
x_trn = x_trn.drop(columns=['Date','Stock','15d_Return','30d_Return', '60d_Return'])

# %%
reg30.fit(x_trn, y_trn30, eval_set=[(x_trn, y_trn30)])

# %%
preds30 = reg30.predict(dow30.loc[dow30['Date'] > pd.to_datetime('2022-01-01')].drop(columns=['15d_Return', '30d_Return', '60d_Return','Date', 'Stock']))

# %%
output30 = dow30.copy()
output30 = output30[['30d_Return','Date']]

# %%
output30 = output30.loc[output30['Date'] > pd.to_datetime('2022-01-01')]
output30['Predicted 30d_Return'] = preds30

# %%
output30['Date'] = output30.index.map(indices_to_dates)
output30['Stock'] = output30.index.map(indices_to_stocks)

# %%
output30['Date'] = pd.to_datetime(output30['Date'])
JanFeb_results30 = output30.loc[output30['Date'] > pd.to_datetime('2022-01-01')]

# %%
JanFeb_results30 = JanFeb_results30.sort_values(by=['Predicted 30d_Return', 'Date'], ascending=True)

# %%
JanFeb_results30.loc[JanFeb_results30['Date'] > pd.to_datetime('2023-02-14')]

# %%
# January/February results from train df (model excluded Jan) achieved 0.0234 mae (+/- 2.3% return on avg)

# %% [markdown]
# ## Profit Analysis in realistic use-case scenario

# %% [markdown]
# Model will be assumed to be executed every 2 weeks, where the top n predicted returns on the day of model execution will be purchased. Then, two weeks later, the positions will be exited, and positions for the n highest predicted returns on that day will be entered. Profit will be averaged by switching the day of model execution (Every other monday->Every other tuesday..etc). An overall avg profit will then be developed using this specific execution strategy. Further optimization work or even a future ML model can tackle the optimal number of n stocks to divide the allocation amongst as well as any staggerred position entry/exit.

# %%
profit_analysis30 = JanFeb_results30.sort_values('Date').dropna()

# %%
profit_analysis30

# %%
# divide profit_analysis15 into results for each day of the business week
pa30mon = profit_analysis30.loc[profit_analysis30['Date'].dt.dayofweek == 0]
pa30tues = profit_analysis30.loc[profit_analysis30['Date'].dt.dayofweek == 1]
pa30wed = profit_analysis30.loc[profit_analysis30['Date'].dt.dayofweek == 2]
pa30th = profit_analysis30.loc[profit_analysis30['Date'].dt.dayofweek == 3]
pa30fri = profit_analysis30.loc[profit_analysis30['Date'].dt.dayofweek == 4]

pa30mon = pa30mon.sort_values(by=['Date', 'Predicted 30d_Return'], ascending=True)
pa30tues = pa30tues.sort_values(by=['Date', 'Predicted 30d_Return'], ascending=True)
pa30wed = pa30wed.sort_values(by=['Date', 'Predicted 30d_Return'], ascending=True)
pa30th = pa30th.sort_values(by=['Date', 'Predicted 30d_Return'], ascending=True)
pa30fri = pa30fri.sort_values(by=['Date', 'Predicted 30d_Return'], ascending=True)

# %%
profits30 = pd.DataFrame(columns=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], index=range(1,10))

# %%
# loop over number of stocks to split positions in each entry, and see which yields best profit
for i in range(1, 10):
    mon = pd.DataFrame(pa30mon.groupby('Date')['Predicted 30d_Return'].nlargest(i)).reset_index().set_index('level_1')
    mon['Stock'] = mon.index.map(indices_to_stocks)
    mon['30d_Return'] = mon.index.map(act_returns_mapping30)
    weeks_mon = mon.groupby('Date')['30d_Return'].mean()
    profits30['Monday'].loc[i] = weeks_mon.mean()
    
    tues = pd.DataFrame(pa30tues.groupby('Date')['Predicted 30d_Return'].nlargest(i)).reset_index().set_index('level_1')
    tues['Stock'] = tues.index.map(indices_to_stocks)
    tues['30d_Return'] = tues.index.map(act_returns_mapping30)
    weeks_tues = tues.groupby('Date')['30d_Return'].mean()
    profits30['Tuesday'].loc[i] = weeks_tues.mean()

    wed = pd.DataFrame(pa30wed.groupby('Date')['Predicted 30d_Return'].nlargest(i)).reset_index().set_index('level_1')
    wed['Stock'] = wed.index.map(indices_to_stocks)
    wed['30d_Return'] = wed.index.map(act_returns_mapping30)
    weeks_wed = wed.groupby('Date')['30d_Return'].mean()
    profits30['Wednesday'].loc[i] = weeks_wed.mean()

    th = pd.DataFrame(pa30th.groupby('Date')['Predicted 30d_Return'].nlargest(i)).reset_index().set_index('level_1')
    th['Stock'] = th.index.map(indices_to_stocks)
    th['30d_Return'] = th.index.map(act_returns_mapping30)
    weeks_th = th.groupby('Date')['30d_Return'].mean()
    profits30['Thursday'].loc[i] = weeks_th.mean()

    fri = pd.DataFrame(pa30fri.groupby('Date')['Predicted 30d_Return'].nlargest(i)).reset_index().set_index('level_1')
    fri['Stock'] = fri.index.map(indices_to_stocks)
    fri['30d_Return'] = fri.index.map(act_returns_mapping30)
    weeks_fri = fri.groupby('Date')['30d_Return'].mean()
    profits30['Friday'].loc[i] = weeks_fri.mean()

# %%
profits30 # shows mean return for entering positions in stocks with the n highest predicted returns on the specified weekday
# over a 15d holding period

# %%
# maximum profit: 1 stock on every sixth tuesday
tues = pd.DataFrame(pa30tues.groupby('Date')['Predicted 30d_Return'].nlargest(1)).reset_index()
tues['Stock'] = tues['level_1'].map(indices_to_stocks)
tues['30d_Return'] = tues['level_1'].map(act_returns_mapping30)
tues1 = tues.loc[(tues.index % 6 == 0)] # Takes the two stocks every third tuesday

# %%
tues1

# %%
mae = tues1.groupby('Date')['30d_Return'].mean()
funds = 1
for month in mae:
    funds *= (1+month)
funds

# %%
funds = 0
allocation = 1.0/6.0
all1, all2, all3, all4, all5, all6 = allocation, allocation, allocation, allocation, allocation, allocation
for num, ret in enumerate(tues['15d_Return']):
    n = num % 6
    if n == 0:
        all1 *= (1+ret)
    elif n == 1:
        all2 *= (1+ret)
    elif n == 2:
        all3 *= (1+ret)
    elif n == 3:
        all4 *= (1+ret)
    elif n == 4:
        all5 *= (1+ret)
    else:
        all6 *= (1+ret)

funds = all1 + all2 + all3 + all4 + all5 + all6
funds

# %%
importances30 = pd.DataFrame(reg30.get_booster().get_score(importance_type='weight'), index=[0]).transpose()
importances30.columns = ['weight']

# %%
importances30.sort_values(by=['weight'], ascending = False)

# %% [markdown]
# ## 60 Day Return Prediction

# %%
reg60 = XGBRegressor()

# %%
reg60.fit(x_trn, y_trn60)

# %%
preds60 = reg60.predict(x_tst)

# %%
print(r2_score(preds60,y_tst60))

# %%
print(mean_absolute_percentage_error(preds60, y_tst60))

# %%
xgb.plot_importance(reg60)
